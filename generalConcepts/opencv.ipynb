# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Canny Edge Detection Algorithm
#
# Comprises of 4 steps
# - Reduce Noise using Gaussian Smoothing.
# - Compute image gradient using Sobel filter.
# - Apply Non-Max Suppression or NMS to just jeep the local maxima
# - Finally, apply Hysteresis thresholding which that 2 threshold values T_upper and T_lower which is used in the Canny() function.

# %%
image=cv2.imread('image.png',cv2.IMREAD_COLOR)
low_threshold=50
high_threshold=150

edge_img=cv2.Canny(image,low_threshold,high_threshold)

fig,axes=plt.subplots(1,2,figsize=(10,5))


axes[0].imshow(image)
axes[0].set_title("Original Image")
axes[0].axis('off')  



axes[1].imshow(edge_img,cmap='gray')
axes[1].set_title("Image with edges")
axes[1].axis('off')  

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Converting grayscale to RGB

# %%
edge_img_add_dim=edge_img[:,:,None]  #add a new dimesnion to existing dimension
edge_img_rgb=np.concat([edge_img_add_dim,edge_img_add_dim,edge_img_add_dim],axis=2)

plt.imshow(edge_img_rgb)
